# %%
import pandas as pd
import pymongo
from pprint import pprint
# Connect to client
from pymongo import MongoClient
client = MongoClient('localhost', 27017)

# %%
# list databases
print('databases:', client.list_database_names())
# Out:
# databases: ['MNISTdebug', 'SACRED_DB', 'admin', 'config', 'local', 'sacred', 'sacred_db_1', 'sacred_db_template', 'sacred_mnist_example']

# %%
# use database of our experiment
db = client['sacred_db_1']
print('Collections of {} db: {}'.format(db.name, db.list_collection_names()))
# Out:
# Collections of sacred_db_1 db: ['runs', 'omniboard.settings', 'fs.files', 'fs.chunks', 'metrics']

# %% [markdown]
# ## show record of one experiment

# %%
exp = list(db.runs.find())[-1]
pprint(exp.keys())
print('Example of a "document" that represents a single experiment:')
pprint(exp)
# Out:
# dict_keys(['_id', 'experiment', 'format', 'command', 'host', 'start_time', 'config', 'meta', 'status', 'resources', 'artifacts', 'captured_out', 'info', 'heartbeat', 'result', 'stop_time'])
# Example of a "document" that represents a single experiment:
# {'_id': 35,
#  'artifacts': [],
#  'captured_out': "INFO - mnist_cnn - Running command 'my_main'\n"
#                  'INFO - mnist_cnn - Started run with ID "35"\n'
#                  'x_train shape: (60000, 28, 28, 1)\n'
#                  '60000 train samples\n'
#                  '10000 test samples\n'
#                  'Metal device set to: Apple M1 Pro\n'
#                  '\n'
#                  'systemMemory: 16.00 GB\n'
#                  'maxCacheSize: 5.33 GB\n'
#                  '\n'
#                  '2022-05-01 11:38:23.080192: I '
#                  'tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] '
#                  'Could not identify NUMA node of platform GPU ID 0, '
#                  'defaulting to 0. Your kernel may not have been built with '
#                  'NUMA support.\n'
#                  '2022-05-01 11:38:23.080506: I '
#                  'tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] '
#                  'Created TensorFlow device '
#                  '(/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB '
#                  'memory) -> physical PluggableDevice (device: 0, name: METAL, '
#                  'pci bus id: <undefined>)\n'
#                  '2022-05-01 11:38:23.280270: W '
#                  'tensorflow/core/platform/profile_utils/cpu_utils.cc:128] '
#                  'Failed to get CPU frequency: 0 Hz\n'
#                  'Epoch 1/3\n'
#                  '2022-05-01 11:38:23.441046: I '
#                  'tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] '
#                  'Plugin optimizer for device_type GPU is enabled.\n'
#                  '467/469 [============================>.] - ETA: 0s - loss: '
#                  '2.2931 - accuracy: 0.11902022-05-01 11:38:29.310954: I '
#                  'tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] '
#                  'Plugin optimizer for device_type GPU is enabled.\n'
#                  '469/469 [==============================] - 6s 13ms/step - '
#                  'loss: 2.2930 - accuracy: 0.1194 - val_loss: 2.2603 - '
#                  'val_accuracy: 0.2809\n'
#                  'Epoch 2/3\n'
#                  '469/469 [==============================] - 6s 14ms/step - '
#                  'loss: 2.2377 - accuracy: 0.2378 - val_loss: 2.1944 - '
#                  'val_accuracy: 0.5222\n'
#                  'Epoch 3/3\n'
#                  '469/469 [==============================] - 6s 13ms/step - '
#                  'loss: 2.1675 - accuracy: 0.3484 - val_loss: 2.1037 - '
#                  'val_accuracy: 0.6292\n'
#                  'Test loss: 2.1036574840545654\n'
#                  'Test accuracy: 0.6292000412940979\n'
#                  'Open omniboard by the following command...\n'
#                  'omniboard -m 127.0.0.1:27017:sacred_db_1\n'
#                  'Then Go to http://localhost:9000\n'
#                  'INFO - mnist_cnn - Completed after 0:00:21\n',
#  'command': 'my_main',
#  'config': {'params_selected': {'batch_size': 128,
#                                 'epochs': 3,
#                                 'img_cols': 28,
#                                 'img_rows': 28,
#                                 'num_classes': 10},
#             'seed': 901688824},
#  'experiment': {'base_dir': '/Users/dingxian/Documents/datascience/ML-sacred-manage/ML-manage-tfexampleV2',
#                 'dependencies': ['keras==2.8.0',
#                                  'numpy==1.22.3',
#                                  'sacred==0.8.2'],
#                 'mainfile': 'run.py',
#                 'name': 'mnist_cnn',
#                 'repositories': [{'commit': '104d537ce850687f3f5870f07686466148a96582',
#                                   'dirty': True,
#                                   'url': 'https://github.com/monchewharry/ML-management.git'},
#                                  {'commit': '104d537ce850687f3f5870f07686466148a96582',
#                                   'dirty': True,
#                                   'url': 'https://github.com/monchewharry/ML-management.git'},
#                                  {'commit': '104d537ce850687f3f5870f07686466148a96582',
#                                   'dirty': True,
#                                   'url': 'https://github.com/monchewharry/ML-management.git'},
#                                  {'commit': '104d537ce850687f3f5870f07686466148a96582',
#                                   'dirty': True,
#                                   'url': 'https://github.com/monchewharry/ML-management.git'}],
#                 'sources': [['run.py', ObjectId('626ea96e2ce5b7eb8ec116f8')],
#                             ['src/data_processing/data_loader.py',
#                              ObjectId('626ea96e2ce5b7eb8ec116fa')],
#                             ['src/models/model.py',
#                              ObjectId('626ea96e2ce5b7eb8ec116fc')],
#                             ['src/train.py',
#                              ObjectId('626ea96e2ce5b7eb8ec116fe')]]},
#  'format': 'MongoObserver-0.7.0',
#  'heartbeat': datetime.datetime(2022, 5, 1, 15, 38, 44, 60000),
#  'host': {'ENV': {},
#           'cpu': 'Apple M1 Pro',
#           'hostname': 'Dingxians-MacBook.local',
#           'os': ['Darwin', 'macOS-12.3.1-arm64-arm-64bit'],
#           'python_version': '3.9.10'},
#  'info': {'metrics': [{'id': '626ea9781efeb44eb15cfa8b', 'name': 'loss'},
#                       {'id': '626ea9781efeb44eb15cfa8d', 'name': 'acc'},
#                       {'id': '626ea9781efeb44eb15cfa8f', 'name': 'val_loss'},
#                       {'id': '626ea9781efeb44eb15cfa91', 'name': 'val_acc'}]},
#  'meta': {'command': 'my_main',
#           'options': {'--beat-interval': None,
#                       '--capture': None,
#                       '--comment': None,
#                       '--debug': False,
#                       '--enforce_clean': False,
#                       '--file_storage': None,
#                       '--force': False,
#                       '--help': False,
#                       '--loglevel': None,
#                       '--mongo_db': None,
#                       '--name': None,
#                       '--pdb': False,
#                       '--print-config': False,
#                       '--priority': None,
#                       '--queue': False,
#                       '--s3': None,
#                       '--sql': None,
#                       '--tiny_db': None,
#                       '--unobserved': False,
#                       'COMMAND': None,
#                       'UPDATE': [],
#                       'help': False,
#                       'with': False}},
#  'resources': [],
#  'result': None,
#  'start_time': datetime.datetime(2022, 5, 1, 15, 38, 22, 787000),
#  'status': 'COMPLETED',
#  'stop_time': datetime.datetime(2022, 5, 1, 15, 38, 44, 58000)}

# %%
exp['info']
# Out:
# {'metrics': [{'id': '626dd34b1efeb44eb15cf07b', 'name': 'loss'},
#   {'id': '626dd34b1efeb44eb15cf07d', 'name': 'accuracy'},
#   {'id': '626dd34b1efeb44eb15cf07f', 'name': 'val_loss'}]}

# %% [markdown]
# ## show configs

# %%
print('Example of configurations of several experiments:\n')
for i, exp in enumerate(list(db.runs.find())[0:3]):
    pprint(exp['config'])
    print('')
# Out:
# Example of configurations of several experiments:
#
# {'params_selected': {'batch_size': 128,
#                      'epochs': 3,
#                      'img_cols': 28,
#                      'img_rows': 28,
#                      'num_classes': 10},
#  'seed': 325123068}
#
# {'params_selected': {'batch_size': 128,
#                      'epochs': 3,
#                      'img_cols': 28,
#                      'img_rows': 28,
#                      'num_classes': 10},
#  'seed': 58624823}
#
# {'batch_size': 128, 'epochs': 3, 'num_classes': 10, 'seed': 396457322}

# %% [markdown]
# ## pandas+

# %%
from collections import OrderedDict
import pandas as pd
import re

def slice_dict(d, keys):
    """ Returns a dictionary ordered and sliced by given keys
        keys can be a list, or a CSV string
    """
    if isinstance(keys, str):
        keys = keys[:-1] if keys[-1] == ',' else keys
        keys = re.split(', |[, ]', keys)

    return dict((k, d[k]) for k in keys)

def sacred_to_df(db_runs, mongo_query=None, ):
    """
    db_runs is usually db.runs
    returns a dataframe that summarizes the experiments, where 
    config and info fields are flattened to their keys.
    Summary DF contains the following columns:
    _id, experiment.name, **config, result, **info, status, start_time
    """
    # get all experiment according to mongo query and represent as a pandas DataFrame    
    df = pd.DataFrame(list(db_runs.find(mongo_query)))

    # Take only the interesting columns
    df = df.loc[:, '_id, experiment, config, result, info, status, start_time'.split(', ')]

    def _summerize_experiment(s):
        """
        Take only the 
        """
        o = OrderedDict()
        o['_id'] = s['_id']
        o['name']=s['experiment']['name']
        o.update(s['config'])
        for key, val in s['info'].items():
            if key != 'metrics':
                o[key] = val 

        o.update(slice_dict(s.to_dict(), 'result, status, start_time'))
        return pd.Series(o)
    
    sum_list = []
    for ix, s in df.iterrows():
        sum_list.append(_summerize_experiment(s))
    df_summary = pd.DataFrame(sum_list).set_index('_id')
    
    return df_summary

# %%
# Get the COMPLETED experiments with dim<=100 and val. accuracy > 85%
query = 'status=="COMPLETED"'
df_summary = sacred_to_df(db.runs).query(query)
# Sort them in descending order (best performer is first).
#df_summary = df_summary.sort_values('val_acc', ascending=False)
display(df_summary)
# Out:
#           name                                    params_selected       seed  \
# _id
# 26   mnist_cnn  {'batch_size': 128, 'epochs': 3, 'img_cols': 2...  325123068
# 27   mnist_cnn  {'batch_size': 128, 'epochs': 3, 'img_cols': 2...   58624823
# 28   mnist_cnn                                                NaN  396457322
# 30   mnist_cnn                                                NaN  123881562
# 32   mnist_cnn  {'batch_size': 128, 'epochs': 3, 'img_cols': 2...  682302499
# 33   mnist_cnn                                                NaN    1427569
# 34   mnist_cnn                                                NaN  114285423
# 35   mnist_cnn  {'batch_size': 128, 'epochs': 3, 'img_cols': 2...  901688824
#
#      result     status              start_time  batch_size  epochs  \
# _id
# 26      NaN  COMPLETED 2022-04-30 21:45:26.074         NaN     NaN
# 27      NaN  COMPLETED 2022-04-30 23:20:45.164         NaN     NaN
# 28      NaN  COMPLETED 2022-05-01 00:24:33.646       128.0     3.0
# 30      NaN  COMPLETED 2022-05-01 12:14:19.625       128.0     3.0
# 32      NaN  COMPLETED 2022-05-01 12:18:00.727         NaN     NaN
# 33      NaN  COMPLETED 2022-05-01 14:46:16.907       128.0     3.0
# 34      NaN  COMPLETED 2022-05-01 14:48:14.020       128.0     3.0
# 35      NaN  COMPLETED 2022-05-01 15:38:22.787         NaN     NaN
#
#      num_classes
# _id
# 26           NaN
# 27           NaN
# 28          10.0
# 30          10.0
# 32           NaN
# 33          10.0
# 34          10.0
# 35           NaN
